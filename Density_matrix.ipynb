# %%
from qiskit import QuantumCircuit
import qiskit.quantum_info as qi
from qiskit.visualization import array_to_latex

# %% [markdown]
# # Defining Input state

# %%
psi0 = qi.Statevector ([0,1,0,0])
psi0.draw('latex')
# Out:
# $$ |01\rangle$$

# %%
qc= QuantumCircuit(2)
qc.h(1)
qc.cx(1,0)
qc.draw('mpl',reverse_bits=True)

# %%
# output state
psi1 = psi0.evolve(qc)
psi1.draw('latex')
# Out:
# $$\frac{\sqrt{2}}{2} |01\rangle+\frac{\sqrt{2}}{2} |10\rangle$$

# %% [markdown]
# # Calculating Density Matrix

# %%
rho1 = qi.DensityMatrix(psi1)
rho1.draw('latex')
# Out:
# $$
#
# \begin{bmatrix}
# 0 & 0 & 0 & 0  \\
#  0 & \frac{1}{2} & \frac{1}{2} & 0  \\
#  0 & \frac{1}{2} & \frac{1}{2} & 0  \\
#  0 & 0 & 0 & 0  \\
#  \end{bmatrix}
# $$

# %%
#rho1.draw('city')

# %% [markdown]
# ## Now if we have a density matrix and we want to evolve it using quantum circuit

# %%
rho2 = qi.DensityMatrix.from_label('l')
rho2.draw('latex')
# Out:
# $$
#
# \begin{bmatrix}
# \frac{1}{2} & \frac{i}{2}  \\
#  - \frac{i}{2} & \frac{1}{2}  \\
#  \end{bmatrix}
# $$

# %%
# we want to evolve it using s gate
s= qi.Operator.from_label('S')
array_to_latex(s)
# Out:
# $$
#
# \begin{bmatrix}
# 1 & 0  \\
#  0 & i  \\
#  \end{bmatrix}
# $$

# %%
rho3 = rho2.evlove(S)
rho3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 rho3 = rho2.evlove(S)
#       2 rho3
#
# AttributeError: 'DensityMatrix' object has no attribute 'evlove'
